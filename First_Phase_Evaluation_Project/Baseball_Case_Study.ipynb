# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:/Users/ankit.srivastava/Downloads/baseball.csv")
df
#url = "https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv"
#bb_data = pd.read_csv(url)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# the data consists of 30 rows and 17 columns. Target variable is first column which is W(the number of wins)
# Since all columns contain only numeric data, it represents a regression problem.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# data set contains of all int64 columns and one float64 column

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there are no null values present in each column of the dataset.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
sb.pairplot(df)

# %%
# Create a 2x3 subplot layout
fig, axes = plt.subplots(nrows=6, ncols=3, constrained_layout=True, figsize=(12, 18))

# List of attributes to plot
attributes = ['R', 'AB', 'H', '2B', '3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']

# Loop through the attributes and create scatterplots
for i, attribute in enumerate(attributes):
    row, col = i // 3, i % 3
    sb.scatterplot(x='W', y=attribute, data=df, ax=axes[row, col])
    axes[row, col].set_title(attribute)

plt.show()

# %% [markdown]
# 'W' target variable has low postive linear relation with 'R', 'H', 'HR', 'SO', 'CG' and 'SHO' features, and high postive linear relation with 'SV', '2B' and 'BB' features.
# 'W' target variable has low negative linear relation with 'AB', '3B', 'E' and 'SB' features , and high negative linear relation with 'RA', 'ER' and 'ERA' features.

# %%
corr =df.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,10))
sb.heatmap(corr,cmap='Blues',annot=True,linewidth=.3)
# Out:
# <AxesSubplot: >

# %%
from scipy import stats
from scipy.stats import zscore

z=np.abs(zscore(df))
print(np.where(z>3))

df_1=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df_1.shape)

plt.figure(figsize=(25,20))
for i in enumerate(df_1):
    plt.subplot(3,4,i[0]+1)
    sb.distplot(df_1[i[1]],color='b')
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))
# with outliers:: (30, 17)
# After removing outliers:: (29, 17)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 13
#      11 plt.figure(figsize=(25,20))
#      12 for i in enumerate(df_1):
# ---> 13     plt.subplot(3,4,i[0]+1)
#      14     sb.distplot(df_1[i[1]],color='b')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1264, in subplot(*args, **kwargs)
#    1261 fig = gcf()
#    1263 # First, search for an existing subplot with a matching spec.
# -> 1264 key = SubplotSpec._from_subplot_args(fig, args)
#    1266 for ax in fig.axes:
#    1267     # if we found an Axes at the position sort out if we can re-use it
#    1268     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1269         # if the user passed no kwargs, re-use
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 from scipy.stats import zscore as zs
#       2 import numpy as np
# ----> 4 f_outlier=df[col[1:]]
#       5 z=np.abs(zs(f_outlier))
#       6 z
#
# TypeError: 'int' object is not subscriptable

# %%
z=np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %% [markdown]
# The variable 'z' holds the zscores values of these features.

# %%
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z.iloc[5,1]
# Out:
# 3.5096470447193067

# %% [markdown]
# this is the outlier value

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_error,r2_score

# Define the features and target variable
X = df.drop(['W'], axis=1)
y = df['W']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Define a dictionary of regression models
models = {
    'Linear Regression': LinearRegression(),
    'Lasso Regression': Lasso(),
    'Ridge Regression': Ridge(),
    'Random Forest Regression': RandomForestRegressor(),
    'Polynomial Regression': make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
}

# Loop through the models and evaluate their performance
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    r2s =r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)

    print(f"Model: {name}")
    print(f"R2S: {r2s}")
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"RMSE: {rmse}")
    print("\n")
# Out:
# Model: Linear Regression
# R2S: 0.6629341689506619
# MAE: 4.044069070628706
# MSE: 21.871827259201496
# RMSE: 4.676732540909464
#
#
# Model: Lasso Regression
# R2S: 0.7471309863134508
# MAE: 3.336080103788562
# MSE: 16.408389332549415
# RMSE: 4.0507270128397215
#
#
# Model: Ridge Regression
# R2S: 0.695458624463626
# MAE: 4.077697556807737
# MSE: 19.761351479249157
# RMSE: 4.445374166394676
#
#
# Model: Random Forest Regression
# R2S: 0.31769032534246633
# MAE: 5.314999999999998
# MSE: 44.274316666666635
# RMSE: 6.65389484938458
#
#
# Model: Polynomial Regression
# R2S: 0.06648138562460981
# MAE: 6.290135093228642
# MSE: 60.57498564391421
# RMSE: 7.78299336013556

# %%
#Using GridSearchCV  for hyperparameter tuning
from sklearn.model_selection import GridSearchCV as GSC#Importing required library

pa={'alpha':[0.001,0.01,0.1,1.0,10.0],'fit_intercept':[True,False],'copy_X':[False,True],'max_iter': [900,1000,1240],'precompute':[False,True]}#defining hyper parameters
gsc=GSC(Lasso(),pa)#creating instance
gsc.fit(X_train,y_train)#fitting data
gsc.best_params_#fetching best parameters
# Out:
# {'alpha': 1.0,
#  'copy_X': False,
#  'fit_intercept': False,
#  'max_iter': 900,
#  'precompute': False}

# %%
#Applying best parameters provided by GridSearchCV
final=Lasso(alpha=1.0,copy_X=False,fit_intercept=False,max_iter=900,precompute=False)

# %%
final.fit(X_train,y_train)#fitting data
pr=final.predict(X_test)#predicting data

print('R2 score :',r2_score(y_test,pr))#printing 
print('Mean Absolute Error:',mean_absolute_error(y_test,pr))#printing
print('Mean Squared Error :',mean_squared_error(y_test,pr))#printing
print('Root Mean Squared Error:',mean_squared_error(y_test,pr,squared=False))#printing
# Out:
# R2 score : 0.8645914857530588
# Mean Absolute Error: 2.7353015055439407
# Mean Squared Error : 8.786508035579294
# Root Mean Squared Error: 2.9642044523917868

# %%
#Conclusion
Predicted_values=final.predict(X_test)#storing predicted values in 'Predicted_values' variable
Original_values=y_test#storing original values in 'Original_values' variable

conclusion=pd.DataFrame({'Predicted Values':Predicted_values,'Original Values':Original_values})#creating new data frame with Predicted and Original values
conclusion
# Out:
#     Predicted Values  Original Values
# 2          78.940023               81
# 28         70.927988               74
# 13         77.929610               76
# 10         86.234306               88
# 26         89.102749               84
# 24         60.518234               63

# %%
import joblib
joblib.dump(Lasso,"Baseball.pkl")
# Out:
# ['Baseball.pkl']
