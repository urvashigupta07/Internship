# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
#reading the data, and converting it into df Dataframe
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
#head of dataset is shown below
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#shape of data is defined
df.shape
# Out:
# (158, 12)

# %%
#detailed information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [raw]
# The information about the data is shown above. Two columns are object type and rest others are float 64.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no null element present in any column of the dataset.

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
sns.pairplot(df)

# %%
top_10_happiness = df.nlargest(10, 'Happiness Rank')
sns.barplot(x='Happiness Rank', y='Country', data=top_10_happiness, palette='viridis')
# Out:
# <AxesSubplot: xlabel='Happiness Rank', ylabel='Country'>

# %%
# Create a 2x2 subplot layout
fig, axes = plt.subplots(nrows=2, ncols=2, constrained_layout=True, figsize=(12, 8))

# Top 10 countries with the highest Economy (GDP per Capita)
sns.barplot(x='Economy (GDP per Capita)', y='Country', data=df.nlargest(10, 'Economy (GDP per Capita)'), ax=axes[0, 0], palette='viridis')

# Top 10 countries with the highest Standard Error
sns.barplot(x='Standard Error', y='Country', data=df.nlargest(10, 'Standard Error'), ax=axes[0, 1], palette='viridis')

# Top 10 countries with the highest Health (Life Expectancy)
sns.barplot(x='Health (Life Expectancy)', y='Country', data=df.nlargest(10, 'Health (Life Expectancy)'), ax=axes[1, 0], palette='viridis')

# Top 10 countries with the highest Freedom
sns.barplot(x='Freedom', y='Country', data=df.nlargest(10, 'Freedom'), ax=axes[1, 1], palette='viridis)

plt.show()

# %%
# Create a 2x3 subplot layout
fig, axes = plt.subplots(nrows=2, ncols=3, constrained_layout=True, figsize=(12, 8))

# List of attributes to plot
attributes = ['Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Family','Dystopia Residual']

# Loop through the attributes and create scatterplots
for i, attribute in enumerate(attributes):
    row, col = i // 3, i % 3
    sns.scatterplot(x=attribute, y='Happiness Score', data=df, ax=axes[row, col])
    axes[row, col].set_title(attribute)

plt.show()

# %%
import plotly.express as px

fig = px.choropleth(df, 
                    locations='Country',
                    locationmode='country names',
                    color='Happiness Score',
                    color_continuous_scale='RdYlGn',
                    hover_name='Country',
                    title='Geographical Visualization of Happiness Score',
                    color_continuous_midpoint=df['Happiness Score'].median(),
                    labels={'Happiness Score': 'Happiness Score'}
                   )

fig.update_geos(projection_type='azimuthal equal area')
fig.show()
# Out:
# <div>                            <div id="539cd09f-8c22-4a6e-bdb6-0f1f9f60a89d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("539cd09f-8c22-4a6e-bdb6-0f1f9f60a89d")) {                    Plotly.newPlot(                        "539cd09f-8c22-4a6e-bdb6-0f1f9f60a89d",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=%{location}\u003cbr\u003eHappiness Score=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Switzerland","Iceland","Denmark","Norway","Canada","Finland","Netherlands","Sweden","New Zealand","Australia","Israel","Costa Rica","Austria","Mexico","United States","Brazil","Luxembourg","Ireland","Belgium","United Arab Emirates",
# ...

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()['Happiness Score']
# Out:
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize =(15,7))
sns.heatmap(df.corr(),annot = True ,linewidths = 0.5,linecolor = 'black' , fmt = '.2f')
# Out:
# <AxesSubplot: >

# %%
collist = df.columns.values
ncol=30
nrow=17
plt.figure(figsize=(ncol,3*ncol))
for i in range(2,len(collist)-1): # here it start from and subtract '-1' from last bcz string does not show outliers
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data =df[collist[i]],color = 'blue',orient = 'v')
    plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
numerical_features = ['Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Family']

rows, cols = len(numerical_features) // 2, 2
fig, axes = plt.subplots(rows, cols, figsize=(12, 12))
fig.suptitle('Distribution of Features', fontsize=16)

for ax, feature in zip(axes.flat, numerical_features):
    sns.distplot(df[feature], ax=ax)
    ax.set_title(f'Distribution of {feature}')
    ax.set_xlabel('')
    ax.set_ylabel('')

plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %%
#removing uncorrelated data as threshold to be +/-0.3 and having more outliers and removing columns which having string data (not helpful in predicting the model)
df = df.drop(['Standard Error','Generosity','Trust (Government Corruption)'],axis=1)

# %%
df = df.drop(['Country','Region','Category'],axis=1)
df
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0                 1            7.587                   1.39651  1.34951
# 1                 2            7.561                   1.30232  1.40223
# 2                 3            7.527                   1.32548  1.36058
# 3                 4            7.522                   1.45900  1.33095
# 4                 5            7.427                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 153             154            3.465                   0.22208  0.77370
# 154             155            3.340                   0.28665  0.35386
# 155             156            3.006                   0.66320  0.47489
# 156             157            2.905                   0.01530  0.41587
# 157             158            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Dystopia Residual
# ...

# %%
from scipy.stats import zscore
zscore_outliers=np.abs(zscore(df))
threshold=3
print('Outliers:- \n',np.where(zscore_outliers>3))
# Out:
# Outliers:-
#  (array([147, 155, 157], dtype=int64), array([3, 6, 3], dtype=int64))

# %%
dfzscore=df[(zscore_outliers<3).all(axis=1)]
print("Before removing outliers::",df.shape)
print("After removing outliers::",dfzscore.shape)
# Out:
# Before removing outliers:: (158, 7)
# After removing outliers:: (155, 7)

# %%
#Splitting the data
x=df.drop(['Happiness Score'],axis=1)
y=df['Happiness Score']

# %%
x.shape
# Out:
# (155, 6)

# %%
y.shape
# Out:
# (155,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_error
from sklearn.metrics import mean_squared_error, r2_score

# %%
#splitting the data into 75% training and 25% testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
# Defining dictionary of regression models
models = {
    'Linear Regression': LinearRegression(),
    'Lasso Regression': Lasso(),
    'Ridge Regression': Ridge(),
    'Decision Tree Regression':DecisionTreeRegressor(),
    'Random Forest Regression': RandomForestRegressor(),
    'Support Vector Regression':SVR(),
    'Polynomial Regression': make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
}

# Loop through the models and evaluating their performance
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)

    print(f"Model: {name}")
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"RMSE: {rmse}")
    print("\n")
# Out:
# Model: Linear Regression
# MAE: 0.09087550654756851
# MSE: 0.013333228223116689
# RMSE: 0.1154695986964391
#
#
# Model: Lasso Regression
# MAE: 0.1109575404423923
# MSE: 0.02035616280686211
# RMSE: 0.14267502516860514
#
#
# Model: Ridge Regression
# MAE: 0.10290976619178707
# MSE: 0.015981217955379542
# RMSE: 0.126416842055873
#
#
# Model: Decision Tree Regression
# MAE: 0.07069230769230768
# MSE: 0.009156948717948718
# RMSE: 0.09569194698588131
#
#
# Model: Random Forest Regression
# MAE: 0.038953589743589735
# MSE: 0.0030941710948716996
# RMSE: 0.05562527388581291
#
#
# Model: Support Vector Regression
# MAE: 0.06683523704923437
# MSE: 0.006541828949162532
# RMSE: 0.08088157360711111
#
#
# Model: Polynomial Regression
# MAE: 0.13089594278580108
# MSE: 0.02787673195731351
# RMSE: 0.16696326529303837

# %% [raw]
# Random Forest Regressor has minimum value of MAE, MSE and RMSE. So further improve its performance lets apply hyperparameter tuning.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Define the hyperparameters and their respective values to search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create the Random Forest Regressor model
rf = RandomForestRegressor(random_state=42)

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the model to find the best hyperparameters
grid_search.fit(x, y)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %%
# Creating Random Forest Regressor with the best hyperparameters
best_rf_model = grid_search.best_estimator_

# Using the best model for predictions
best_predictions = best_rf_model.predict(x_test)

# %%
import joblib

# %%
#save the best score model in joblib
joblib.dump(best_rf_model,'Happiness_Score_Dataset_Model')
# Out:
# ['Happiness_Score_Dataset_Model']

# %%
# Create a DataFrame to display the actual and predicted values
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Display the first few rows of the results
print(results.head())
# Out:
#      Actual  Predicted
# 118   4.518   4.297047
# 80    5.194   4.721730
# 96    4.898   4.993677
# 0     7.587   7.507053
# 69    5.548   5.351101
